# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mass_estimation as me
from tqdm import tqdm

# %% [markdown]
# ## Read in the data

# %%
#Define some file paths
git_folder_loc = '/home/stba7609/'
model_tracks_path = 'NII_nebular_phase/analysis/model_tracks/'
all_tracks_path = 'NII_nebular_phase/analysis/observed_tracks/'
Ib_tracks_path = 'SECRETO/WISEREP_Ib/Ib_tracks/'
Ic_tracks_path = 'SECRETO/WISEREP_Ic/Ic_tracks/'
IIb_tracks_path = 'SECRETO/WISEREP_IIb/IIb_tracks/'

# %%
#Create arrays with file names for the different types
Ib_names = np.array(['SN1985F', 'SN1996aq', 'SN2004ao', 'SN2009jf',
                    'SN2015ah', 'SN2004dk', 'SN2012au', 'SNMASTEROTJ1204'
                     , 'SN2008D', 'SN2007Y', 'SN2007C', 'SN2006ld', 'SN2004gq',
                    'SN2019odp'])
Ic_names = np.array(['SN1987M', 'SN1997dq', 'SN1998bw', 'SN2003gf', 'SN2004aw', 'SN2007gr', 'SN2007I',
                    'SN2011bm', 'SN2013ge', 'SN2015fn', 'SN2019yz', 'SNPTF12gzk'])
IIb_names = np.array(['SN1993J', 'SN1996cb', 'SN2001ig', 'SN2003bg', 'SN2008ax',
                      'SN2008aq', 'SN2008bo', 'SN2009K', 'SN2011dh', 'SN2011ei', 'SN2011hs',
                      'SN2013df', 'SN2020acat','SN2022crv', 'SNASASSN14az', 'SNPTF12os', 'iPTF13bvn'])
#eIIb_names = np.array(['SN1993J', 'SN2008ax', 'SN2011dh', 'SN2011hs', 'SN2013df'])

all_names = np.concatenate((Ib_names, Ic_names, IIb_names))

# %%
#Read in the model tracks
string_masses = np.array(['3p30', '4p00', '5p00', '6p00', '8p00']) #Write as 'xpxx'
model_masses = np.array([3.3, 4.0, 5.0, 6.0, 8.0])
version_name = 'v2p0'
model_tracks = []
for i in range(len(string_masses)):
    track = np.loadtxt(git_folder_loc + model_tracks_path + 'NII_track_he_' + string_masses[i] + '_' + version_name + '.csv',
              delimiter = ',')
    model_tracks.append(track)

# %% [markdown]
# ## Get the masses

# %%
#The cell doing all the work
all_m_pred_low, all_m_pred_mid, all_m_pred_high = np.zeros(len(all_names)), np.zeros(len(all_names)), np.zeros(len(all_names))
for i in tqdm(range(len(all_names))):
    
    sn_name = all_names[i]
    
    #Read in the track
    obs_track = np.loadtxt(git_folder_loc + all_tracks_path + 'NII_track_' + sn_name + '.csv',
              delimiter = ',') 
    
    #Mask out values before a given epoch
    cut_epoch = 200 #Days post explosion
    
    
    #Get the mass
    print('Getting mass for ', sn_name)
    
    if len(obs_track.shape) > 1:
        
        epoch_mask = np.where(obs_track[:, 0] > cut_epoch)[0]
        obs_track = obs_track[epoch_mask]
        
        if obs_track == [] or len(obs_track) == 0: #No epochs before cut off, so no estimate can be made
            mass_68_left, best_mass, mass_68_right = -1, -1 , -1
        else:
            best_mass, mass_68_left, mass_68_right = me.mass_determinator_mcmc(obs_track[:, 0], obs_track[:, 1], obs_track[:, 2], model_tracks=model_tracks, plot = True)
    else:
        if obs_track[0] < cut_epoch: #No epochs before cut off, so no estimate can be made
            mass_68_left, best_mass, mass_68_right = -1, -1 , -1
        else:
            best_mass, mass_68_left, mass_68_right = me.mass_determinator_mcmc(np.array([obs_track[0]]), np.array([obs_track[1]]), np.array([obs_track[2]]), model_tracks=model_tracks, plot = True)
    
    all_m_pred_low[i] = mass_68_left
    all_m_pred_mid[i] = best_mass
    all_m_pred_high[i] = mass_68_right
# Out:
#   0%|                                                    | 0/43 [00:00<?, ?it/s]
# Getting mass for  SN1985F
# The final score plot:
#   2%|█                                           | 1/43 [00:01<00:56,  1.35s/it]
# Best fitting mass:  6.00  +  0.30  -  0.30
# Getting mass for  SN1996aq
# /tmp/ipykernel_27688/3194531569.py:23: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   if obs_track == [] or len(obs_track) == 0: #No epochs before cut off, so no estimate can be made
# The final score plot:
#   5%|██                                          | 2/43 [00:02<00:59,  1.45s/it]
# Best fitting mass:  5.50  +  1.40  -  0.70
# Getting mass for  SN2004ao
# The final score plot:
#   7%|███                                         | 3/43 [00:04<01:00,  1.50s/it]
# Best fitting mass:  8.00  +  0.00  -  1.70
# Getting mass for  SN2009jf
# The final score plot:
#   9%|████                                        | 4/43 [00:05<00:59,  1.52s/it]
# Best fitting mass:  8.00  +  0.00  -  0.70
# Getting mass for  SN2015ah
# Getting mass for  SN2004dk
# The final score plot:
#  14%|██████▏                                     | 6/43 [00:07<00:41,  1.11s/it]
# Best fitting mass:  7.70  +  0.30  -  0.90
# Getting mass for  SN2012au
# The final score plot:
#  16%|███████▏                                    | 7/43 [00:09<00:49,  1.39s/it]
# Best fitting mass:  8.00  +  0.00  -  0.40
# Getting mass for  SNMASTEROTJ1204
# The final score plot:
#  19%|████████▏                                   | 8/43 [00:13<01:10,  2.01s/it]
# Best fitting mass:  4.90  +  0.40  -  0.40
# Getting mass for  SN2008D
# Getting mass for  SN2007Y
# The final score plot:
#  23%|██████████                                 | 10/43 [00:16<01:01,  1.86s/it]
# Best fitting mass:  3.30  +  0.60  -  0.00
# Getting mass for  SN2007C
# Getting mass for  SN2006ld
# Getting mass for  SN2004gq
# The final score plot:
#  30%|█████████████                              | 13/43 [00:18<00:37,  1.23s/it]
# Best fitting mass:  8.00  +  0.00  -  0.70
# Getting mass for  SN2019odp
# The final score plot:
#  33%|██████████████                             | 14/43 [00:19<00:38,  1.32s/it]
# Best fitting mass:  8.00  +  0.00  -  0.70
# Getting mass for  SN1987M
# Getting mass for  SN1997dq
# The final score plot:
#  37%|████████████████                           | 16/43 [00:22<00:34,  1.27s/it]
# Best fitting mass:  7.30  +  0.70  -  1.40
# Getting mass for  SN1998bw
# The final score plot:
#  40%|█████████████████                          | 17/43 [00:25<00:41,  1.58s/it]
# Best fitting mass:  8.00  +  0.00  -  0.50
# Getting mass for  SN2003gf
# Getting mass for  SN2004aw
# The final score plot:
#  44%|███████████████████                        | 19/43 [00:26<00:31,  1.32s/it]
# Best fitting mass:  6.40  +  1.60  -  1.10
# Getting mass for  SN2007gr
# Getting mass for  SN2007I
# The final score plot:
#  49%|█████████████████████                      | 21/43 [00:28<00:25,  1.16s/it]
# Best fitting mass:  4.90  +  0.10  -  0.20
# Getting mass for  SN2011bm
# The final score plot:
#  51%|██████████████████████                     | 22/43 [00:31<00:31,  1.51s/it]
# Best fitting mass:  5.30  +  0.60  -  0.60
# Getting mass for  SN2013ge
# The final score plot:
#  53%|██████████████████████▉                    | 23/43 [00:33<00:33,  1.67s/it]
# Best fitting mass:  7.20  +  0.80  -  1.20
# Getting mass for  SN2015fn
# The final score plot:
#  56%|████████████████████████                   | 24/43 [00:35<00:31,  1.68s/it]
# Best fitting mass:  8.00  +  0.00  -  0.30
# Getting mass for  SN2019yz
# The final score plot:
#  58%|█████████████████████████                  | 25/43 [00:37<00:32,  1.83s/it]
# Best fitting mass:  7.10  +  0.90  -  2.30
# Getting mass for  SNPTF12gzk
# The final score plot:
#  60%|██████████████████████████                 | 26/43 [00:39<00:32,  1.94s/it]
# Best fitting mass:  8.00  +  0.00  -  0.60
# Getting mass for  SN1993J
# The final score plot:
#  63%|███████████████████████████                | 27/43 [00:50<01:09,  4.32s/it]
# Best fitting mass:  4.00  +  0.70  -  0.70
# Getting mass for  SN1996cb
# The final score plot:
#  65%|████████████████████████████               | 28/43 [00:52<00:53,  3.58s/it]
# Best fitting mass:  3.60  +  1.30  -  0.30
# Getting mass for  SN2001ig
# The final score plot:
#  67%|█████████████████████████████              | 29/43 [00:54<00:44,  3.19s/it]
# Best fitting mass:  8.00  +  0.00  -  0.60
# Getting mass for  SN2003bg
# The final score plot:
#  70%|██████████████████████████████             | 30/43 [00:57<00:42,  3.24s/it]
# Best fitting mass:  5.30  +  0.70  -  0.60
# Getting mass for  SN2008ax
# The final score plot:
#  72%|██████████████████████████████▉            | 31/43 [01:00<00:37,  3.14s/it]
# Best fitting mass:  4.20  +  0.50  -  0.50
# Getting mass for  SN2008aq
# The final score plot:
#  74%|████████████████████████████████           | 32/43 [01:02<00:29,  2.70s/it]
# Best fitting mass:  4.00  +  0.60  -  0.60
# Getting mass for  SN2008bo
# The final score plot:
#  77%|█████████████████████████████████          | 33/43 [01:04<00:24,  2.43s/it]
# Best fitting mass:  3.30  +  0.90  -  0.00
# Getting mass for  SN2009K
# The final score plot:
#  79%|██████████████████████████████████         | 34/43 [01:05<00:19,  2.20s/it]
# Best fitting mass:  4.20  +  0.30  -  0.40
# Getting mass for  SN2011dh
# The final score plot:
#  81%|███████████████████████████████████        | 35/43 [01:11<00:25,  3.22s/it]
# Best fitting mass:  3.90  +  0.30  -  0.30
# Getting mass for  SN2011ei
# The final score plot:
#  84%|████████████████████████████████████       | 36/43 [01:13<00:19,  2.75s/it]
# Best fitting mass:  3.30  +  0.40  -  0.00
# Getting mass for  SN2011hs
# The final score plot:
#  86%|█████████████████████████████████████      | 37/43 [01:15<00:16,  2.78s/it]
# Best fitting mass:  3.30  +  0.60  -  0.00
# Getting mass for  SN2013df
# Getting mass for  SN2020acat
# Getting mass for  SN2022crv
# The final score plot:
#  93%|████████████████████████████████████████   | 40/43 [01:18<00:05,  1.75s/it]
# Best fitting mass:  7.50  +  0.50  -  1.10
# Getting mass for  SNASASSN14az
# Getting mass for  SNPTF12os
# The final score plot:
#  98%|██████████████████████████████████████████ | 42/43 [01:20<00:01,  1.42s/it]
# Best fitting mass:  4.40  +  0.90  -  0.90
# Getting mass for  iPTF13bvn
# The final score plot:
# 100%|███████████████████████████████████████████| 43/43 [01:22<00:00,  1.92s/it]
# Best fitting mass:  4.50  +  1.30  -  0.70

# %% [markdown]
# ## Make a nice plot

# %%
#Lets read in the predicted masses from the literature

metadata_Ib = np.loadtxt(git_folder_loc + 'SECRETO/WISEREP_Ib/metadata.csv',
              delimiter = ',', dtype = str)
metadata_Ic = np.loadtxt(git_folder_loc + 'SECRETO/WISEREP_Ic/metadata.csv',
              delimiter = ',', dtype = str)
metadata_IIb = np.loadtxt(git_folder_loc + 'SECRETO/WISEREP_IIb/metadata.csv',
              delimiter = ',', dtype = str)

metadata_all = np.concatenate((metadata_Ib, metadata_Ic, metadata_IIb))

# %%
print(metadata_all)
# Out:
# [['SN1985F' 'NGC_4618' '0.00173' '--' '--' '0.019' '--' '--' '--' '--'
#   '--' '--' '--' '--']
#  ['SN1996aq' 'NGC_5584' '0.0056' '23' '--' '0.035' '--' '--' '--' '--'
#   '--' '--' '--' '--']
#  ['SN2019odp' 'UGC_12373' '0.01435' '64' '0.00' '0.17' '0.25' '4' '7'
#   '6.4' '18' '38' '--' '--']
#  ['SN2015Q' 'NGC_3888' '0.00792' '34' '--' '0.01' '--' '--' '--' '--'
#   '--' '--' '--' '--']
#  ['SN2015ah' '--' '0.016' '--' '--' '0.072' '--' '--' '--' '--' '--' '--'
#   '--' '--']
#  ['SN2012au' 'NGC_4790' '0.0045' '23.5' '0.02' '0.043' '--' '4.0' '4.0'
#   '5.1' '--' '--' '--' '--']
#  ['SN2009jf' 'NGC_7479' '0.008' '32' '0.0-0.1' '0.112' '0.2' '5' '7' '6'
#   '25' '30' '--' '--']
#  ['SN2008D' 'NGC_2770' '0.00674' '29.5' '0.62' '0.022' '0.09' '7' '7' '6'
#   '30' '30' '--' '--']
#  ['SN2007Y' 'NGC_1187' '0.004657' '19.3' '0.09' '0.022' '0.06' '1' '2'
#   '0.8' '10' '13' '3.3' '3.3']
#  ['SN2007C' 'NGC_4981' '0.005602' '--' '--' '0.037' '--' '--' '--' '--'
#   '--' '--' '--' '--']
#  ['SN2006ld' 'UGC_348' '0.014' '--' '--' '0.015' '--' '--' '--' '--' '--'
#   '--' '--' '--']
#  ['SN2004gq' 'NGC_1832' '0.006462' '--' '--' '0.064' '--' '--' '--' '--'
#   '--' '--' '--' '--']
#  ['SN2004dk' 'NGC_6118' '0.0052' '22.8' '0.00' '0.142' '--' '--' '--'
#   '--' '--' '--' '--' '--  ']
#  ['SN2004ao' 'UGC_10862' '0.005641' '--' '--' '0.092' '--' '--' '--' '--'
#   '--' '--' '--' '--  ']
#  ['SNMASTEROTJ1204' 'NGC_4080' '0.00189' '15' '--' '0.023' '--' '--' '--'
#   '--' '--' '--' '--' '--  ']
#  ['SN1998bw' 'ESO 184-G82' '0.008499' '36' '0.00' '0.065' '0.6' '10' '10'
#   '30' '25' '--' '9' '14']
#  ['SN1987M' 'NGC_2715' '0.004413' '20.7' '0.005' '0.44' '--' '1' '--'
#   '--' '--' '--' '--' '--']
#  ['SN2019yz' '--' '0.00639' '--' '--' '0.101' '--' '--' '--' '--' '--'
#   '--' '--' '--']
#  ['SN2015fn' 'anon' '0.054' '232' '0.00' '0.062' '0.42' '9.7' '10.9'
#   '2.2' '35' '--' '--' '--']
#  ['SN2013ge' 'NGC_3287' '0.004356' '23.7' '0.047' '0.02' '--' '2' '3'
#   '1.5' '--' '--' '--' '--']
#  ['SN2011bm' 'IC_3918' '0.022' '92' '0.032' '0.032' '0.6' '7' '17' '12'
#   '30' '50' '--' '--']
#  ['SN2007I' '--' '0.021638' '--' '--' '0.026' '--' '--' '--' '--' '--'
#   '--' '--' '--']
#  ['SN2007gr' 'NGC_1058' '0.001728' '9.3' '0.03' '0.062' '0.09' '1' '3'
#   '--' '--' '--' '--' '--']
#  ['SN2004aw' 'NGC_3997' '0.0163' '65' '0.35' '0.02-0.10' '0.3' '3.5' '8'
#   '--' '--' '--' '--' '--']
#  ['SN2003gf' 'MCG-04-52-26' '0.0087' '--' '--' '0.029' '--' '--' '--'
#   '--' '--' '--' '--' '--']
#  ['SN1997dq' 'NGC_3810' '0.003196' '23' '0.00' '0.00' '0.16' '2' '2.7'
#   '--' '--' '--' '--' '--']
#  ['SNPTF12gzk' 'SDSS J221241.53+003042.7' '0.01377' '57.8' '0.00' '0.14'
#   '0.36' '6' '12' '7' '25' '35' '--' '--']
#  ['SN1993J' 'M81' '-0.000113' '2.6-3.3' '0.15' '0.00' '0.07' '--' '--'
#   '1.2' '13' '16' '3.5' '4.5']
#  ['SN2022crv' 'NGC3054' '0.0081' '31.6' '0.146' '0.0642' '0.18' '2.78'
#   '2.78' '1.01' '16' '22' '6' '8']
#  ['SN2020acat' 'PGC037027' '0.007932' '35.3' '0.00' '0.021' '0.13' '2.3'
#   '2.3' '1.2' '15' '20' '--' '--']
#  ['SN2013df' 'NGC_4414' '0.002395' '16.6' '--' '0.017' '0.06' '3.9' '3.9'
#   '2.7' '13' '17' '--' '--']
#  ['SN2011hs' 'IC_5267' '0.0057' '26.4' '0.16' '0.011' '0.04' '0.23'
#   '0.23' '0.85' '12' '15' '3' '4']
#  ['SN2011ei' 'NGC_6925' '0.009313' '28.5' '0.18' '0.059' '0.047' '1.0'
#   '1.0' '--' '--' '--' '3' '4']
#  ['SN2011dh' 'M51' '0.002' '7.8' '0.04' '0.031' '0.075' '2.2' '2.2' '0.8'
#   '12' '16' '3.3' '4']
#  ['SN2009K' 'NGC_1620' '0.0117' '--' '--' '0.0491' '--' '--' '--' '--'
#   '--' '--' '--' '--']
#  ['SN2008bo' 'NGC_6643' '0.00495' '--' '--' '0.053' '--' '--' '--' '--'
#   '--' '--' '--' '--']
#  ['SN2008aq' 'MCG-02-33-20' '0.007972' '34' '0.027' '0.045' '--' '--'
#   '--' '--' '--' '--' '--' '--']
#  ['SN2008ax' 'NGC_4490' '0.001931' '9.6' '0.38' '0.022' '0.11' '3' '3'
#   '3.5' '--' '--' '--' '--']
#  ['SN2003bg' 'MCG_05-10-15' '0.004403' '19.6' '--' '0.020' '--' '--' '--'
#   '--' '--' '--' '--' '--']
#  ['SN2001ig' 'NGC_7424' '0.003049' '11.5' '--' '0.009' '--' '--' '--'
#   '--' '--' '--' '--' '--']
#  ['SN1996cb' 'NGC_3510' '0.002372' '--' '0' '0.027' '--' '2' '5' '1' '--'
#   '--' '--' '--']
#  ['SNASASSN14az' 'GALEXASC_J234448.27-020653.4' '0.006731' '23' '--'
#   '0.028' '--' '--' '--' '--' '--' '--' '--' '--']
#  ['iPTF13bvn' 'NGC_5806' '0.00449' '27' '0.08' '0.045' '0.072' '1.5'
#   '2.6' '0.9' '--' '--' '3.6' '5.0']
#  ['SNPTF12os' 'NGC_5806' '0.00449' '26.8' '0.29' '0.045' '0.063' '1.3'
#   '2.7' '0.54' '--' '--' '3.4' '5']]

# %%
#First, we create a plot for Mf vs Mf
fig, ax = plt.subplots(1)

colours = ['orange', 'red', 'green', 'blue']
sn_types = ['Ib', 'Ic', 'IIb', 'eIIb']
literature_errs_list, prediction_errs_list, plot_inds = [], [], []
m_pred_mid_f_list, m_lit_mid_f_list, accepted_names = [], [], []
no_lit, lim_list = False, []

for i in range(len(metadata_all)):
    literature_errs, predictions_errs = 0, 0
    lolims, uplims = None, None #These are for plotting errorbars later
    
    lit_name = metadata_all[i, 0]
    print(lit_name)
    
    #if lit_name != 'SNiPTF13bvn':
    #    continue
    
    try:
        prediction_index = np.where(lit_name == all_names )[0][0]
    except:
        continue
        
    accepted_names.append(lit_name)
    
    #Define the predicted Mhe values for this object
    m_pred_low, m_pred_mid, m_pred_high = all_m_pred_low[prediction_index], all_m_pred_mid[prediction_index], all_m_pred_high[prediction_index] 
    m_pred_low_f = me.Mhe_i_to_Mhe_f(m_pred_low)
    m_pred_mid_f = me.Mhe_i_to_Mhe_f(m_pred_mid)
    m_pred_high_f = me.Mhe_i_to_Mhe_f(m_pred_high)
    
    #print(lit_name, m_pred_low, m_pred_mid, m_pred_high)
    #print(m_pred_low_f, m_pred_mid_f, m_pred_high_f)
    
    #Get the literature values for this object
    if metadata_all[i, -2] != '--' and metadata_all[i, -1] != '--': #If Mhe,i is available, translate Mhe,i to Mf
        m_he_low, m_he_high = float(metadata_all[i, -2]), float(metadata_all[i, -1])
        m_lit_low_f, m_lit_high_f = me.Mhe_i_to_Mhe_f(m_he_low), me.Mhe_i_to_Mhe_f(m_he_high)
        m_lit_mid_f = (m_lit_low_f + m_lit_high_f)/2
        
        print(m_he_low, m_he_high)
    elif lit_name not in IIb_names and metadata_all[i, 7] != '--' and metadata_all[i, 8] != '--': #If Mej is available, use that
        m_ej_low, m_ej_high = float(metadata_all[i, 7]), float(metadata_all[i, 8])
        m_lit_low_f, m_lit_high_f = me.Mej_to_Mhe_f(m_ej_low), me.Mej_to_Mhe_f(m_ej_high)
        m_lit_mid_f = (m_lit_low_f + m_lit_high_f)/2
        print(m_ej_low, m_ej_high)
    else:
        no_lit = True
        m_lit_low_f, m_lit_mid_f, m_lit_high_f = -5, -5, -5
     
    print(m_lit_low_f, m_lit_mid_f, m_lit_high_f)
    print()
            
            
    #Check for plotting if we have lower or upper limits
    offset = 0
    this_ms = 10
    if m_pred_mid >= 8: #As our grid stops here, our predictions can only give lower limits
        m_pred_low_f, m_pred_mid_f, m_pred_high_f = m_pred_low_f, m_pred_low_f, m_pred_low_f
        
        #if m_lit_mid_f >= me.Mhe_i_to_Mhe_f(8.0): #Only lower limits exist: give a special symbol
        #    m_lit_low_f, m_lit_mid_f, m_lit_high_f = m_lit_low_f, m_lit_low_f, m_lit_low_f
        #    this_marker = 'h'
        #    
        #    lim_list.append(4)
        
        #else:
        this_marker = '^'

        lim_list.append(2)
            
    elif m_pred_mid <= 3.3: #As our grid stops here, our predictions can only give upper limits
        m_pred_low_f, m_pred_mid_f, m_pred_high_f = m_pred_high_f, m_pred_high_f, m_pred_high_f #No errs, as this is an upper limit
        
        #if m_lit_mid_f <= me.Mhe_i_to_Mhe_f(3.3):
        #    m_lit_low_f, m_lit_mid_f, m_lit_high_f = m_lit_high_f, m_lit_high_f, m_lit_high_f
        #    this_marker = 'h'
            
        #    lim_list.append(3)
        
        #else:
        this_marker = 'v'

        lim_list.append(1)
    else:
        this_marker = '.'
        this_ms = 15
        
        lim_list.append(0)
        
    prediction_errs = np.array([[m_pred_mid_f-m_pred_low_f,
                                     m_pred_high_f-m_pred_mid_f]]).T
    
    if no_lit == True:
        pass
    else:
        literature_errs = np.array([[m_lit_mid_f-m_lit_low_f, 
                                          m_lit_high_f-m_lit_mid_f]]).T
        
        
    #This is put in by hand, as it saves a lot of code that only would serve 2 SNe:
    if lit_name == 'SN2011bm':
        this_marker = '>'
    elif lit_name == 'SN2015fn':
        this_marker = 'h'
        
            
    #Give the right colour
    if lit_name in Ib_names:
        plot_ind = 0
    elif lit_name in Ic_names:
        plot_ind = 1
    elif lit_name in IIb_names:
        plot_ind = 2
    
    if no_lit == True:
        literature_errs_list.append([-5, -5])
        m_lit_mid_f_list.append(-5)
    else:
        literature_errs_list.append(literature_errs)
        m_lit_mid_f_list.append(m_lit_mid_f)
        
        ax.errorbar(x = m_lit_mid_f,
                    y = m_pred_mid_f+offset,
                    yerr = prediction_errs,
                    xerr = literature_errs,
                    fmt = '.', ms = this_ms, lw = 1, marker = this_marker, capsize = 5,
                    color = colours[plot_ind], alpha = 0.8)
        

    #Make sure that things with no prediction also get a -1 assigned:
    if all_m_pred_low[prediction_index] == -1:
        prediction_errs = np.array([[0, 
                                     0]]).T
        m_pred_mid_f = -1
        
        
    prediction_errs_list.append(prediction_errs)
    plot_inds.append(plot_ind)
    m_pred_mid_f_list.append(m_pred_mid_f)
    
    no_lit = False
    
    
    
    
    
#And now the plot specifics

#Getting the labels
ax.scatter(x = -1, y = -1, label = 'Ib', color = colours[0])
ax.scatter(x = -1, y = -1, label = 'Ic', color = colours[1])
ax.scatter(x = -1, y = -1, label = 'IIb', color = colours[2])

#Shade the areas not outside of our working range
ax.fill_between(x = [2, 8.5], y1 = 5.64, y2 = 8.5, color = 'gray', alpha = 0.5)
ax.fill_between(x = [2, 8.5], y1 = 2, y2 = 2.67, color = 'gray', alpha = 0.5)
#ax.fill_between(x = [5.64, 8.5], y1 = 5.64, y2 = 8.5, color = 'gray', alpha = 0.5)
#ax.fill_between(x = [2, 2.67], y1 = 2, y2 = 2.67, color = 'gray', alpha = 0.5)
    
ax.set_xlim(2, 8.5)
ax.set_ylim(2, 8.5)
ax.plot(np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 100), np.linspace(ax.get_ylim()[0], ax.get_ylim()[1], 100), linestyle = '--', c = 'black')
ax.set_xlabel('Literature $M_{preSN}$ [M$_{\odot}$]')
ax.set_ylabel('Predicted $M_{preSN}$ [M$_{\odot}$]')
ax.grid()


ax.legend(fontsize = 12, frameon = True)
fig.set_size_inches(4, 4)
plt.savefig('Figure_x_Mass_Estimates_vs_Lit.png', dpi = 300, bbox_inches = 'tight')
plt.show()
# Out:
# SN1985F
# -5 -5 -5
#
# SN1996aq
# -5 -5 -5
#
# SN2019odp
# 4.0 7.0
# 5.694999999999999 6.8675 8.04
#
# SN2015Q
# SN2015ah
# -5 -5 -5
#
# SN2012au
# 4.0 4.0
# 5.694999999999999 5.694999999999999 5.694999999999999
#
# SN2009jf
# 5.0 7.0
# 6.606216216216216 7.323108108108108 8.04
#
# SN2008D
# 7.0 7.0
# 8.04 8.04 8.04
#
# SN2007Y
# 3.3 3.3
# 2.67 2.67 2.67
#
# SN2007C
# -5 -5 -5
#
# SN2006ld
# -5 -5 -5
#
# SN2004gq
# -5 -5 -5
#
# SN2004dk
# -5 -5 -5
#
# SN2004ao
# -5 -5 -5
#
# SNMASTEROTJ1204
# -5 -5 -5
#
# SN1998bw
# 9.0 14.0
# 6.2 7.119999999999999 8.04
#
# SN1987M
# -5 -5 -5
#
# SN2019yz
# -5 -5 -5
#
# SN2015fn
# 9.7 10.9
# 8.04 8.04 8.04
#
# SN2013ge
# 2.0 3.0
# 3.6034375 4.132601102941177 4.661764705882353
#
# SN2011bm
# 7.0 17.0
# 8.04 8.04 8.04
#
# SN2007I
# -5 -5 -5
#
# SN2007gr
# 1.0 3.0
# 2.67 3.6658823529411766 4.661764705882353
#
# SN2004aw
# 3.5 8.0
# 5.211774193548386 6.625887096774193 8.04
#
# SN2003gf
# -5 -5 -5
#
# SN1997dq
# 2.0 2.7
# 3.6034375 3.964751536885246 4.326065573770492
#
# SNPTF12gzk
# 6.0 12.0
# 7.804285714285713 7.922142857142856 8.04
#
# SN1993J
# 3.5 4.5
# 2.81 3.1500000000000004 3.49
#
# SN2022crv
# 6.0 8.0
# 4.45 5.045 5.64
#
# SN2020acat
# -5 -5 -5
#
# SN2013df
# -5 -5 -5
#
# SN2011hs
# 3.0 4.0
# 2.4599999999999995 2.8049999999999997 3.15
#
# SN2011ei
# 3.0 4.0
# 2.4599999999999995 2.8049999999999997 3.15
#
# SN2011dh
# 3.3 4.0
# 2.67 2.91 3.15
#
# SN2009K
# -5 -5 -5
#
# SN2008bo
# -5 -5 -5
#
# SN2008aq
# -5 -5 -5
#
# SN2008ax
# -5 -5 -5
#
# SN2003bg
# -5 -5 -5
#
# SN2001ig
# -5 -5 -5
#
# SN1996cb
# -5 -5 -5
#
# SNASASSN14az
# -5 -5 -5
#
# iPTF13bvn
# 3.6 5.0
# 2.88 3.3499999999999996 3.82
#
# SNPTF12os
# 3.4 5.0
# 2.74 3.2800000000000002 3.82
# /tmp/ipykernel_27688/2775390872.py:124: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "." (-> marker='.'). The keyword argument will take precedence.
#   ax.errorbar(x = m_lit_mid_f,

# %% [markdown]
# ## Store all the masses

# %%
print(sorted(accepted_names))
print(sorted(metadata_all[:, 0]))
# Out:
# ['SN1985F', 'SN1987M', 'SN1993J', 'SN1996aq', 'SN1996cb', 'SN1997dq', 'SN1998bw', 'SN2001ig', 'SN2003bg', 'SN2003gf', 'SN2004ao', 'SN2004aw', 'SN2004dk', 'SN2004gq', 'SN2006ld', 'SN2007C', 'SN2007I', 'SN2007Y', 'SN2007gr', 'SN2008D', 'SN2008aq', 'SN2008ax', 'SN2008bo', 'SN2009K', 'SN2009jf', 'SN2011bm', 'SN2011dh', 'SN2011ei', 'SN2011hs', 'SN2012au', 'SN2013df', 'SN2013ge', 'SN2015ah', 'SN2015fn', 'SN2019odp', 'SN2019yz', 'SN2020acat', 'SN2022crv', 'SNASASSN14az', 'SNMASTEROTJ1204', 'SNPTF12gzk', 'SNPTF12os', 'iPTF13bvn']
# ['SN1985F', 'SN1987M', 'SN1993J', 'SN1996aq', 'SN1996cb', 'SN1997dq', 'SN1998bw', 'SN2001ig', 'SN2003bg', 'SN2003gf', 'SN2004ao', 'SN2004aw', 'SN2004dk', 'SN2004gq', 'SN2006ld', 'SN2007C', 'SN2007I', 'SN2007Y', 'SN2007gr', 'SN2008D', 'SN2008aq', 'SN2008ax', 'SN2008bo', 'SN2009K', 'SN2009jf', 'SN2011bm', 'SN2011dh', 'SN2011ei', 'SN2011hs', 'SN2012au', 'SN2013df', 'SN2013ge', 'SN2015Q', 'SN2015ah', 'SN2015fn', 'SN2019odp', 'SN2019yz', 'SN2020acat', 'SN2022crv', 'SNASASSN14az', 'SNMASTEROTJ1204', 'SNPTF12gzk', 'SNPTF12os', 'iPTF13bvn']

# %%
final_product = np.zeros((len(all_names), 9), dtype = object)

#Safety check:
if len(all_names) != len(metadata_all):
    print('WARNING: You may be missing some SN data')

#First add the data which does have literature predictions
for i in range(len(accepted_names)):
    
    final_product[i, 0] = accepted_names[i]
    final_product[i, 1] = sn_types[plot_inds[i]]
    final_product[i, 2] = '{:.1f}'.format(m_pred_mid_f_list[i])
    final_product[i, 3] = '{:.1f}'.format(prediction_errs_list[i][0][0])
    final_product[i, 4] = '{:.1f}'.format(prediction_errs_list[i][1][0])
    
    if m_lit_mid_f_list[i] == -5: #This means there are no literature vals:
        final_product[i, 5] = '--'
        final_product[i, 6] = '--'
        final_product[i, 7] = '--'
        
    else: #There exist literature valls!
        final_product[i, 5] = '{:.1f}'.format(m_lit_mid_f_list[i])
        final_product[i, 6] = '{:.1f}'.format(literature_errs_list[i][0][0])
        final_product[i, 7] = '{:.1f}'.format(literature_errs_list[i][1][0])
        
    final_product[i, 8] = lim_list[i]
    
print(final_product)
fmt = '%s,%s,%s,%s,%s,%s,%s,%s,%s'
    
np.savetxt('mass_predictions.csv', final_product, fmt = fmt, delimiter = ',', header = '## name,type,m_pred_mid_f,m_pred_low_f,m_pred_high_f,m_lit_mid_f,m_lit_low_f,m_lit_high_f')
# Out:
# WARNING: You may be missing some SN data
# [['SN1985F' 'Ib' '4.5' '0.2' '0.2' '--' '--' '--' 0]
#  ['SN1996aq' 'Ib' '4.1' '0.5' '0.9' '--' '--' '--' 0]
#  ['SN2019odp' 'Ib' '5.2' '0.0' '0.0' '6.9' '1.2' '1.2' 2]
#  ['SN2015ah' 'Ib' '-1.0' '0.0' '0.0' '--' '--' '--' 1]
#  ['SN2012au' 'Ib' '5.4' '0.0' '0.0' '5.7' '0.0' '0.0' 2]
#  ['SN2009jf' 'Ib' '5.2' '0.0' '0.0' '7.3' '0.7' '0.7' 2]
#  ['SN2008D' 'Ib' '-1.0' '0.0' '0.0' '8.0' '0.0' '0.0' 1]
#  ['SN2007Y' 'Ib' '3.1' '0.0' '0.0' '2.7' '0.0' '0.0' 1]
#  ['SN2007C' 'Ib' '-1.0' '0.0' '0.0' '--' '--' '--' 1]
#  ['SN2006ld' 'Ib' '-1.0' '0.0' '0.0' '--' '--' '--' 1]
#  ['SN2004gq' 'Ib' '5.2' '0.0' '0.0' '--' '--' '--' 2]
#  ['SN2004dk' 'Ib' '5.5' '0.6' '0.1' '--' '--' '--' 0]
#  ['SN2004ao' 'Ib' '4.6' '0.0' '0.0' '--' '--' '--' 2]
#  ['SNMASTEROTJ1204' 'Ib' '3.8' '0.3' '0.3' '--' '--' '--' 0]
#  ['SN1998bw' 'Ic' '5.4' '0.0' '0.0' '7.1' '0.9' '0.9' 2]
#  ['SN1987M' 'Ic' '-1.0' '0.0' '0.0' '--' '--' '--' 1]
#  ['SN2019yz' 'Ic' '5.2' '1.5' '0.5' '--' '--' '--' 0]
#  ['SN2015fn' 'Ic' '5.5' '0.0' '0.0' '8.0' '0.0' '0.0' 2]
#  ['SN2013ge' 'Ic' '5.2' '0.7' '0.5' '4.1' '0.5' '0.5' 0]
#  ['SN2011bm' 'Ic' '4.0' '0.4' '0.4' '8.0' '0.0' '0.0' 0]
#  ['SN2007I' 'Ic' '3.8' '0.1' '0.1' '--' '--' '--' 0]
#  ['SN2007gr' 'Ic' '-1.0' '0.0' '0.0' '3.7' '1.0' '1.0' 1]
#  ['SN2004aw' 'Ic' '4.7' '0.7' '1.0' '6.6' '1.4' '1.4' 0]
#  ['SN2003gf' 'Ic' '-1.0' '0.0' '0.0' '--' '--' '--' 1]
#  ['SN1997dq' 'Ic' '5.2' '0.8' '0.4' '4.0' '0.4' '0.4' 0]
#  ['SNPTF12gzk' 'Ic' '5.2' '0.0' '0.0' '7.9' '0.1' '0.1' 2]
#  ['SN1993J' 'IIb' '3.1' '0.5' '0.5' '3.2' '0.3' '0.3' 0]
#  ['SN2022crv' 'IIb' '5.3' '0.6' '0.3' '5.0' '0.6' '0.6' 0]
#  ['SN2020acat' 'IIb' '-1.0' '0.0' '0.0' '--' '--' '--' 1]
#  ['SN2013df' 'IIb' '-1.0' '0.0' '0.0' '--' '--' '--' 1]
#  ['SN2011hs' 'IIb' '3.1' '0.0' '0.0' '2.8' '0.3' '0.3' 1]
#  ['SN2011ei' 'IIb' '3.0' '0.0' '0.0' '2.8' '0.3' '0.3' 1]
#  ['SN2011dh' 'IIb' '3.1' '0.2' '0.2' '2.9' '0.2' '0.2' 0]
#  ['SN2009K' 'IIb' '3.2' '0.2' '0.3' '--' '--' '--' 0]
#  ['SN2008bo' 'IIb' '3.3' '0.0' '0.0' '--' '--' '--' 1]
#  ['SN2008aq' 'IIb' '3.1' '0.5' '0.4' '--' '--' '--' 0]
#  ['SN2008ax' 'IIb' '3.3' '0.3' '0.3' '--' '--' '--' 0]
#  ['SN2003bg' 'IIb' '4.0' '0.4' '0.4' '--' '--' '--' 0]
#  ['SN2001ig' 'IIb' '5.3' '0.0' '0.0' '--' '--' '--' 2]
#  ['SN1996cb' 'IIb' '3.0' '0.3' '0.8' '--' '--' '--' 0]
#  ['SNASASSN14az' 'IIb' '-1.0' '0.0' '0.0' '--' '--' '--' 1]
#  ['iPTF13bvn' 'IIb' '3.6' '0.5' '0.8' '3.3' '0.5' '0.5' 0]
#  ['SNPTF12os' 'IIb' '3.4' '0.6' '0.6' '3.3' '0.5' '0.5' 0]]

# %% [markdown]
# ## Legacy

# %%
#First, we create a plot for Mej vs Mej
fig, ax = plt.subplots(1)

border_counter1, border_counter2 = 0, 0 #These numbers are used to create an offset in the plot at Mpred = 3.3 and 8.0
colours = ['orange', 'red', 'green']
sn_types = ['Ib', 'Ic', 'IIb']

for i in range(len(all_names)):
    lit_name = metadata_all[i, 0]
    
    try:
        prediction_index = np.where(lit_name == all_names )[0][0]
    except:
        continue
    
    #Define the predicted Mhe values for this object
    m_pred_low, m_pred_mid, m_pred_high = all_m_pred_low[prediction_index], all_m_pred_mid[prediction_index], all_m_pred_high[prediction_index] 
    m_pred_low_ej = me.Mhe_f_to_Mej(me.Mhe_i_to_Mhe_f(m_pred_low))
    m_pred_mid_ej = me.Mhe_f_to_Mej(me.Mhe_i_to_Mhe_f(m_pred_mid))
    m_pred_high_ej = me.Mhe_f_to_Mej(me.Mhe_i_to_Mhe_f(m_pred_high))
    
    #Define the literature values for this object
    if lit_name in IIb_names: #Type IIbs can not use Mej, so calc from Mhe in stead
        if metadata_all[i, -2] != '--' and metadata_all[i, -1] != '--':
            m_he_low, m_he_high = float(metadata_all[i, -2]), float(metadata_all[i, -1])
            m_lit_low_ej, m_lit_high_ej = me.Mhe_f_to_Mej(me.Mhe_i_to_Mhe_f(m_he_low)), me.Mhe_f_to_Mej(me.Mhe_i_to_Mhe_f(m_he_high))
            m_lit_mid_ej = (m_lit_low_ej + m_lit_high_ej)/2
        else:
            continue
    else: 
        if metadata_all[i, 7] != '--' and metadata_all[i, 8] != '--': #For Ib and Ic, first look if Mej is available
            m_lit_low_ej, m_lit_high_ej = float(metadata_all[i, 7]), float(metadata_all[i, 8])
            m_lit_mid_ej = (m_lit_low_ej + m_lit_high_ej)/2
        elif metadata_all[i, -2] != '--' and metadata_all[i, -1] != '--': #If it is not available, translate Mhe to Mej
            m_he_low, m_he_high = float(metadata_all[i, -2]), float(metadata_all[i, -1])
            m_lit_low_ej, m_lit_high_ej = me.Mhe_f_to_Mej(me.Mhe_i_to_Mhe_f(m_he_low)), me.Mhe_f_to_Mej(me.Mhe_i_to_Mhe_f(m_he_high))
            m_lit_mid_ej = (m_lit_low_ej + m_lit_high_ej)/2
        else:
            continue
            
            
    #Check for plotting if we have lower or upper limits
    offset = 0
    if m_pred_low >= 8 or m_pred_mid >=  8 or m_pred_high >= 8:
        this_marker = '^'
        m_pred_low_ej, m_pred_high_ej = m_pred_mid_ej, m_pred_mid_ej #No errs, as this is a lower limit
        border_counter1 += 0.1
        offset = border_counter1
    elif m_pred_low <= 3.3 or m_pred_mid <= 3.3 or m_pred_high <= 3.3:
        m_pred_low_ej, m_pred_high_ej = m_pred_mid_ej, m_pred_mid_ej #No errs, as this is an upper limit
        this_marker = 'v'
        border_counter2 -= 0.1
        offset = border_counter2
    else:
        this_marker = '.'
            
            
    literature_errs = np.array([[m_lit_mid_ej-m_lit_low_ej, 
                                          m_lit_high_ej-m_lit_mid_ej]]).T
    prediction_errs = np.array([[m_pred_mid_ej-m_pred_low_ej,
                                     m_pred_high_ej-m_pred_mid_ej]]).T
            
    #Give the right colour
    if lit_name in Ib_names:
        plot_ind = 0
    elif lit_name in Ic_names:
        plot_ind = 1
    elif lit_name in IIb_names:
        plot_ind = 2
    else:
        sys.exit()
        
    
    ax.errorbar(x = m_lit_mid_ej,
                    y = m_pred_mid_ej+offset,
                    yerr = prediction_errs,
                    xerr = literature_errs,
                    fmt = '.', ms = 15, lw = 1, marker = this_marker, capsize = 5, color = colours[plot_ind])
    
    
#And now the plot specifics

#Getting the labels
ax.scatter(x = -1, y = -1, label = 'Ib', color = 'orange')
ax.scatter(x = -1, y = -1, label = 'Ic', color = 'red')
ax.scatter(x = -1, y = -1, label = 'IIb', color = 'green')
    
ax.set_xlim(0, 17)
ax.set_ylim(0, 17)
ax.plot(np.linspace(ax.get_xlim()[0], ax.get_xlim()[1], 100), np.linspace(ax.get_ylim()[0], ax.get_ylim()[1], 100), linestyle = '--', c = 'black')
ax.set_xlabel('Literature M$_{ej}$ [M$_{\odot}$]')
ax.set_ylabel('Predicted $M_{ej}$ [M$_{\odot}$]')
ax.grid()


ax.legend(fontsize = 14)
fig.set_size_inches(6, 6)
#plt.savefig('Mass_predictions_260923.png')
plt.show()
