# %%
#Imports
import numpy as np
import matplotlib.pyplot as plt
import os
import add_funcs_231023 as af
from scipy import integrate
from astropy.io import ascii

# %%
#File paths
this_dir = os.getcwd()
obs_dir = this_dir[:-23] + 'SECRETO/WISEREP_IIb/Standardised_spectra/'

fnames = sorted(os.listdir(obs_dir))

# %%
#Read in all observations from SN2011dh
wl_list, flux_list = [], []
epochs = []

for i in range(len(fnames)):
    if '2011dh' in fnames[i]:
    
        spectrum = np.loadtxt(obs_dir + fnames[i] , delimiter = ',')

        wl_left, wl_right = 5000, 8000
        zoom_mask = (spectrum[:, 0] > wl_left) * (spectrum[:, 1] < wl_right)

        wl_zoom, spec_zoom = spectrum[:, 0][zoom_mask], spectrum[:, 1][zoom_mask]

        wl_list.append(wl_zoom)
        flux_list.append(spec_zoom)
        epochs.append(int(fnames[i][-7:-4])+20) #Store epochs to later select a subset for plotting. +20 as it is peaklight

# %%
#Get the best fit params for all obs of SN2011dh

popt_best, pcov_best, score_g, tau_best, g_check = af.simultaneous_fitting_g(wl_list, flux_list, epochs, plot = True)
if g_check == True: #The velocity for the Gaussian NII is accepted, so we continue with a gaussian
    shape = 'g'
    pass
elif g_check == False: #The velocity is too high, meaning a tophat is a better fit
    popt_best, pcov_best, score_th, tau_best = af.simultaneous_fitting_th(wl_list, flux_list, epochs, plot = True)
    shape = 'th'
    print('The scores are for g and th: ', score_g, score_th, tau_best)
# Out:
#   0%|                                                    | 0/35 [00:00<?, ?it/s]
# 80 7.812931653751329e-07 7.812931653751329e-07
# 80 7.267432653729245e-07 7.812931653751329e-07
# 80 6.762576702092475e-07 7.812931653751329e-07
# 80 6.131467350338297e-07 7.812931653751329e-07
# 80 5.981379092894383e-07 7.812931653751329e-07
# 80 5.270401690063966e-07 7.812931653751329e-07
# 80 4.842079876264893e-07 7.812931653751329e-07
# 80 4.83538565230988e-07 7.812931653751329e-07
#   3%|█▎                                          | 1/35 [00:00<00:31,  1.07it/s]
# 80 4.720454146971881e-07 7.812931653751329e-07
#   6%|██▌                                         | 2/35 [00:01<00:30,  1.10it/s]
# 82 4.667666176359714e-07 7.530018664595767e-07
#   9%|███▊                                        | 3/35 [00:02<00:28,  1.12it/s]
# 84 4.6267903513214254e-07 7.267874720800601e-07
# 86 4.6158287446395576e-07 7.02571056851745e-07
#  11%|█████                                       | 4/35 [00:03<00:27,  1.13it/s]
# 86 4.596372784945301e-07 7.02571056851745e-07
# 88 4.566259729628147e-07 6.802019191957067e-07
#  14%|██████▎                                     | 5/35 [00:04<00:26,  1.14it/s]
# 90 4.5267760274038164e-07 6.595903787826558e-07
#  17%|███████▌                                    | 6/35 [00:05<00:25,  1.14it/s]
# 92 4.496053963813227e-07 6.406654456570467e-07
#  20%|████████▊                                   | 7/35 [00:06<00:24,  1.14it/s]
# 94 4.4725914732429564e-07 6.233575600787052e-07
#  23%|██████████                                  | 8/35 [00:07<00:23,  1.14it/s]
# 96 4.455461140455423e-07 6.075988824485947e-07
#  26%|███████████▎                                | 9/35 [00:07<00:22,  1.14it/s]
# 98 4.4452188092500657e-07 5.933235156063892e-07
#  29%|████████████▎                              | 10/35 [00:08<00:21,  1.15it/s]
# 100 4.4406553494978046e-07 5.804651495038172e-07
# 100%|███████████████████████████████████████████| 35/35 [00:40<00:00,  1.17s/it]
# [array([6.31330486e+03, 6.58883708e+03, 6.64081892e-15, 5.18141007e-16,
#        9.96429954e+01, 9.58400096e+01]), array([6.31376070e+03, 6.59000000e+03, 5.61170363e-15, 3.70148478e-16,
#        9.59089682e+01, 9.56000000e+01]), array([6.30877150e+03, 6.57240497e+03, 4.17873980e-15, 3.42015811e-16,
#        8.27124600e+01, 9.19200000e+01]), array([6.30791634e+03, 6.57513153e+03, 3.66000072e-15, 3.00732634e-16,
#        8.30181696e+01, 9.18400000e+01]), array([6.30823376e+03, 6.57497555e+03, 7.92254394e-15, 6.48689198e-16,
#        8.18012178e+01, 9.14400000e+01]), array([6.30603354e+03, 6.57921924e+03, 2.57177416e-15, 2.19864005e-16,
#        7.87453116e+01, 8.88800000e+01]), array([6.30842709e+03, 6.56007800e+03, 1.60639374e-15, 1.64349502e-16,
#        7.95654555e+01, 9.32900000e+01]), array([6.30734105e+03, 6.56685310e+03, 1.17417410e-15, 1.42317512e-16,
#        7.94983793e+01, 9.23300000e+01]), array([6.31140513e+03, 6.57637112e+03, 4.57938207e-16, 7.07136641e-17,
#        7.74392831e+01, 8.96500000e+01]), array([6.31504171e+03, 6.58187855e+03, 1.73096200e-16, 3.26009529e-17,
#        7.61635317e+01, 8.43444268e+01])]
# The uncertainties for the plot above are: [2.81577811e-01 1.91601707e+00 1.69873626e-17 7.98786622e-18
#  4.19615610e-01 2.08665669e+00]
# The uncertainties for the plot above are: [6.19042227e-01 5.12376454e+00 3.33541698e-17 1.53486779e-17
#  9.27866777e-01 5.57341290e+00]
# The uncertainties for the plot above are: [3.16446256e-02 3.15667643e-01 1.82603898e-18 9.17345865e-19
#  4.90205110e-02 3.34403553e-01]
# The uncertainties for the plot above are: [2.63407653e-02 2.61470134e-01 1.34096760e-18 6.74484433e-19
#  4.09420645e-02 2.76622056e-01]
# The uncertainties for the plot above are: [3.86301541e-02 3.87770465e-01 4.34608135e-18 2.17569879e-18
#  6.00492183e-02 4.10119546e-01]
# The uncertainties for the plot above are: [4.34066467e-02 4.24919921e-01 1.72278658e-18 8.55740706e-19
#  6.83055957e-02 4.46163176e-01]
# The uncertainties for the plot above are: [6.19556459e-02 6.32368625e-01 1.66328773e-18 9.02133133e-19
#  9.56653299e-02 6.80219344e-01]
# The uncertainties for the plot above are: [3.83481273e-02 3.31984750e-01 7.70654740e-19 4.22547037e-19
#  5.88417749e-02 3.54315702e-01]
# The uncertainties for the plot above are: [2.13840484e-02 1.45963934e-01 1.76374285e-19 9.67677669e-20
#  3.29793424e-02 1.53964983e-01]
# The uncertainties for the plot above are: [6.19041170e-02 3.38606318e-01 1.99286811e-19 1.11271963e-19
#  9.63532334e-02 3.52302133e-01]
#
# The opt taulist for gaussian is [2.0, 2.0, 1.0, 1.0, 1.0, 1.0, 0.5, 0.5, 0.5, 0.5]

# %%
#From the best fit params, get the NII amount

fitted_NII, fitted_sigma = [], []
for k in range(len(epochs)):
    wl, flux = wl_list[k], flux_list[k]
    popt, pcov = popt_best[k], pcov_best[k]
    integrated_NII_flux_my_method, sigma_NII = af.observed_flux_from_fit(wl, flux, popt, pcov, wl_left, wl_right, shape)

    fitted_NII.append(integrated_NII_flux_my_method*100)
    fitted_sigma.append(sigma_NII*100)
    print("The NII doublet carries: ", "{0:.3g}".format(integrated_NII_flux_my_method*100), "% of the selected region")
# Out:
# The SNR for this spectrum is: 13.658102230645351
# The relative imporantce of SNR_sigma to fit_sigma is: 2.744490863987493
# The NII doublet carries:  3.59 % of the selected region
# The SNR for this spectrum is: 4.946869076457411
# The relative imporantce of SNR_sigma to fit_sigma is: 2.825585238537741
# The NII doublet carries:  3.32 % of the selected region
# The SNR for this spectrum is: 50.92241316699938
# The relative imporantce of SNR_sigma to fit_sigma is: 4.344777934094499
# The NII doublet carries:  5.62 % of the selected region
# The SNR for this spectrum is: 39.99004817700361
# The relative imporantce of SNR_sigma to fit_sigma is: 6.658906122433234
# The NII doublet carries:  5.49 % of the selected region
# The SNR for this spectrum is: 40.813049667224846
# The relative imporantce of SNR_sigma to fit_sigma is: 4.374961707228074
# The NII doublet carries:  5.55 % of the selected region
# The SNR for this spectrum is: 43.536297918793615
# The relative imporantce of SNR_sigma to fit_sigma is: 3.6160981170797712
# The NII doublet carries:  6.62 % of the selected region
# The SNR for this spectrum is: 24.93922358891087
# The relative imporantce of SNR_sigma to fit_sigma is: 4.393453304318053
# The NII doublet carries:  8.33 % of the selected region
# The SNR for this spectrum is: 56.55387237116974
# The relative imporantce of SNR_sigma to fit_sigma is: 3.6443483728468626
# The NII doublet carries:  10.1 % of the selected region
# The SNR for this spectrum is: 123.49564596891685
# The relative imporantce of SNR_sigma to fit_sigma is: 3.6874819938259735
# The NII doublet carries:  13.9 % of the selected region
# The SNR for this spectrum is: 67.29335978921794
# The relative imporantce of SNR_sigma to fit_sigma is: 2.7549110761076117
# The NII doublet carries:  15.5 % of the selected region

# %%
#Plot a subset of epochs
plot_epochs = np.array([155, 201, 239, 292, 359, 415])


fig, ax = plt.subplots(2, 3, figsize =  (10, 5), sharex = True, sharey = True)
                       
for i in range(len(plot_epochs)):
                       
    index = np.where(plot_epochs[i] == np.array(epochs))[0][0]
    wl_data_zoom, flux_data_zoom = wl_list[index], flux_list[index]
    
    OI_region = (wl_data_zoom > 6100) * (wl_data_zoom < 6900)
    normalisation = np.max(flux_data_zoom[OI_region])

    ax[int(i/3), i%3].plot(wl_data_zoom, flux_data_zoom/normalisation, c = 'k', alpha = 0.3)
    
    #Also plot the continuum removed flux
    flux_data_zoom_corr = af.continuum_remover(wl_data_zoom, flux_data_zoom)
    ax[int(i/3), i%3].plot(wl_data_zoom, flux_data_zoom_corr/normalisation, c = 'green')
    
    
    if tau_best[index] < 0.1:
        ax[int(i/3), i%3].plot(wl_data_zoom, af.gaussian(wl_data_zoom, *popt_best[index][::2])/normalisation, c = 'fuchsia', linestyle = '--')
        ax[int(i/3), i%3].plot(wl_data_zoom, af.gaussian(wl_data_zoom, *popt_best[index][::2])/normalisation + af.gaussian(wl_data_zoom, *popt_best[index][1::2])/normalisation, c = 'k', linestyle = '--')

    else:
        ax[int(i/3), i%3].plot(wl_data_zoom, af.escatt(wl_data_zoom, *popt_best[index][::2], tau_best[i])/normalisation, c = 'fuchsia', linestyle = '--')
        ax[int(i/3), i%3].plot(wl_data_zoom, af.escatt(wl_data_zoom, *popt_best[index][::2], tau_best[i])/normalisation + af.gaussian(wl_data_zoom, *popt_best[index][1::2])/normalisation, c = 'k', linestyle = '--')

    
    ax[int(i/3), i%3].plot(wl_data_zoom, af.gaussian(wl_data_zoom, *popt_best[index][1::2])/normalisation, c = 'gold', linestyle = '--')
    
    
    trans = ax[int(i/3), i%3].get_xaxis_transform()
    velocity_fwhm = abs(af.v_from_labda(popt_best[index][1]-popt_best[index][5], popt_best[index][1]))
    fig.text(6350, 0.7, s = '$V_{FWHM, NII}$ = ' + '{:.4g}'.format( np.sqrt(2*np.log(2)) *velocity_fwhm) + ' km/s', transform = trans)
    
    fig.text(6540, 0.8, s = 't = ' + '{:.3g}'.format(plot_epochs[i]) + 'd', transform = trans, c = 'red')
    
#To get the labels right, the following subsection
ax[0, 0].plot([0, 1], [0, 1], c = 'k', label = 'Observed Flux', alpha = 0.3)
ax[0, 0].plot([0, 1], [0, 1], c = 'green', label = 'Continuum Corrected Flux')
ax[0, 0].plot([0, 1], [0, 1], c = 'k', label = 'Total Fit', linestyle = '--')
ax[0, 0].plot([0, 1], [0, 1], c = 'fuchsia', label = 'OI Fit', linestyle = '--')
ax[0, 0].plot([0, 1], [0, 1], c = 'gold', label = 'NII Fit', linestyle = '--')


ax[0, 0].set_xlim(6100, 6900)
ax[0, 0].set_ylim(0, 1)

fig.text(0.42, 0.02, s = 'Rest Wavelength [Å]', fontsize = 14, c = 'black')
fig.text(0.07, 0.36, s = 'Normalised flux', fontsize = 14, c = 'black', rotation = 90)

plt.figlegend(bbox_to_anchor=(0.03, 0.93, 1, 0.0), loc= 'center',
              borderaxespad = 0, handletextpad = 0.3, ncol=10 ,columnspacing=1.6, frameon= False)

fig.savefig('Figure_x_Example_of_Multi_epoch_Fit_For_2011dh.pdf', dpi = 300, bbox_inches = 'tight')
plt.show()
